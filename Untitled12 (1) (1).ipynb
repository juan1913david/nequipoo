# %% [markdown]
# ![Diagrama sin título.drawio.png](data:image/png;base64,...)

# %%
#profe yo quise crear la cuenta de una vez entonces para ingresar la clave es 1234
#si desea crear una cuenta de ahorro tiene que darle a la opcion de salir para poder crearla porque es aparte de la cuenta 
#se ingresa con 1 usuario y le va a decir la cantidad que tiene en la cuenta ya que se pone como monto=20000
class Datos:
    def __init__(self,cuenta,propietario,saldo):
        self.cuenta = cuenta
        self.propietario = propietario
        self.saldo = saldo
    
    def getSaldo(self):
      return self.saldo
        
    def getCuenta(self):
        return self.cuenta
    def getPropietario(self):
        return self.propietario

    def mostrarCuenta(self):
        print("\nCuenta: " +self.getCuenta()+"\nPropietario: " +self.getPropietario()+"\nSaldo: " +self.getSaldo())


class Banco:

    monto= 20000
    print("        BIENVENIDO A BANCO PLATA")

    contraseña= "1234"

    intento = input("Introduce la contraseña para ingresar a tu cuenta: ")
    while intento != contraseña:
      print("La contraseña no es correcta.")
      intento = input("intentalo otra vez: ")
    print("Contraseña correcta-Cuenta segura")
    print("Bienvenido a tu banco")
    def operaciones(self):
        self.opcion = int(input('''
    ------------------------------------------
  POR FAVOR INDIQUE QUE OPERACION DESEA REALIZAR.. 
        1. CONSULTAR BALANCE
        2. DEPOSITO A CUENTA
        3. RETIRO DE EFECTIVO
        4. SALIR
        5. SI DESEAS CREAR UNA CUENTA DE AHORRO DEBES SALIR DEL BANCO("4")
        '''))
        self.control=0
        while self.control==0:
            if self.opcion==1:
                self.consultabalance()
            elif self.opcion==2:
                self.depositar()
            elif self.opcion==3:
                self.retirar()
            elif self.opcion==4:
                self.control=1
                self.salir()
            else:
                print("LO SENTIMOS OPCION NO VALIDA!, INTENTE DE NUEVO.. ")
                self.operaciones()


    def consultabalance(self):
        print("SU BALANCE DISPONIBLE ES: ", self.monto)
        print("¿DESEA REALIZAR OTRA OPERACION?")
        self.operaciones()

    def depositar(self):
        self.deposito = int(input("INDIQUE LA CANTIDAD A DEPOSITAR... "))
        self.monto=self.monto + self.deposito
        self.consultabalance()

    def retirar(self):
        self.retiro = int(input("INDIQUE LA CANTIDAD A RETIRAR... "))
        self.control = 0
        while self.control==0:
            if self.retiro > self.monto:
                print('''USTED NO POSEE FONDOS SUFICIENTES PARA ESTE RETIRO
                POR FAVOR INTENTE DE NUEVO..
                --------------------------------------------''')
                self.retiro = int(input("INDIQUE LA CANTIDAD A RETIRAR... "))
            elif self.retiro<= self.monto:
                self.monto=self.monto-self.retiro
                self.control=1
                print("CANTIDAD RETIRADA: ", self.retiro)
                self.consultabalance()

      


    def salir(self):
        print("=======================================")
        print("GRACIAS POR USAR NUESTROS SERVICIOS!")
        print("=======================================")


cuenta = input("ingresa tu telefono: ")
propietario = input("Ingresa tu nombre: ")
e = Datos(cuenta,propietario,saldo="20000")
e.mostrarCuenta()
ejecucion = Banco()
ejecucion.operaciones()

class Cuentah:
   monto1=0
   def __init__(self):
    print("crear cuenta ahorro ")
    self.cedula = int(input("ingrese la cedula: "))
    self.correo = (input("ingrese un correo: "))
    self.contraseña = int(input("ingresa una contraseña"))
    self.telefono = int(input("ingresa el telefono"))

class Ahorro(Cuentah):
  
  def __init__(self):
    super().__init__()
    self.apellido=input("apellido")

  def crear(self):
        self.deposito = int(input('INDIQUE LA CANTIDAD A AHORRAR... '))
        self.monto1=self.monto1 + self.deposito
        print("Se ahorró su dinero")
        
pc1 = Ahorro()
pc1.crear()
# Out:
#         BIENVENIDO A BANCO PLATA
# Introduce la contraseña para ingresar a tu cuenta: 1234
# Contraseña correcta-Cuenta segura
# Bienvenido a tu banco
# ingresa tu telefono: 127171
# Ingresa tu nombre: juan
#
# Cuenta: 127171
# Propietario: juan
# Saldo: 20000
#
#     ------------------------------------------
#   POR FAVOR INDIQUE QUE OPERACION DESEA REALIZAR..
#         1. CONSULTAR BALANCE
#         2. DEPOSITO A CUENTA
#         3. RETIRO DE EFECTIVO
#         4. SALIR
#         5. SI DESEAS CREAR UNA CUENTA DE AHORRO DEBES SALIR DEL BANCO("4")
#         4
# ...
# GRACIAS POR USAR NUESTROS SERVICIOS!
# ...
# crear cuenta ahorro
